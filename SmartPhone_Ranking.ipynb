# %%
import pandas  as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# **Feature Column Details**
#
# Battery_power - Total energy a battery can store in one time measured in mAh
#
# Blue - Has bluetooth or not
#
# Clock_speed - speed at which microprocessor executes instructions
#
# Dual_sim - Has dual sim support or not
#
# Fc - Front Camera mega pixels
#
# Four_g - Has 4G or not
#
# Int_memory - Internal Memory in Gigabytes
#
# M_dep - Mobile Depth in cm
#
# Mobile_wt - Weight of mobile phone
#
# N_cores - Number of cores of processor
#
# Pc - Primary Camera mega pixels
#
# Px_heig Px_height - Pixel Resolution Height
#
# Px_width - Pixel Resolution Width
#
# Ram - Random Access Memory in Mega Bytes
#
# Sc_h - Screen Height of mobile in cm
#
# Sc_w - Screen Width of mobile in cm
#
# Talk_time - longest time that a single battery charge will last
#
# Three_g - Has 3G or not
#
# Touch_screen - Has touch screen or not
#
# Wifi - Has wifi or not
#
# Price_range - This is the target variable with value of 0(low cost), 1 (medium cost), 2(high cost) and 3(very high cost).

# %%
df = pd.read_csv("/content/MobileTrain.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
#checking Null Values
df.isna().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
#checking The no. of unique values
df.nunique()
# Out:
# battery_power    1094
# blue                2
# clock_speed        26
# dual_sim            2
# fc                 20
# four_g              2
# int_memory         63
# m_dep              10
# mobile_wt         121
# n_cores             8
# pc                 21
# px_height        1137
# px_width         1109
# ram              1562
# sc_h               15
# sc_w               19
# talk_time          19
# three_g             2
# touch_screen        2
# wifi                2
# price_range         4
# dtype: int64

# %%
df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
fig, axes = plt.subplots(2, 3, figsize=(16, 10))
fig .suptitle("counting the mobiles features")
sns.countplot(ax=axes[0, 0], data=df, x='three_g', color="m")
sns.countplot(ax=axes[0, 1], data=df, x='touch_screen',color="r")
sns.countplot(ax=axes[0, 2], data=df, x='four_g',color="g")
sns.countplot(ax=axes[1,0], data=df, x='wifi')
sns.countplot(ax=axes[1,1],data = df, x ='fc' )
sns.countplot(ax=axes[1,2],data = df, x ='dual_sim')
# Out:
# <Axes: xlabel='dual_sim', ylabel='count'>

# %%
sns.set(rc = {'figure.figsize':(5,5)})
sns.countplot(data = df, x ='price_range' )
# Out:
# <Axes: xlabel='price_range', ylabel='count'>

# %%
for i in df:
    if(df[i].nunique()<30):
        sns.countplot(x=df[i])
        plt.show()

# %%
df1 = df
df1["is_bluetooth"]=''
for i in range(len(df1)):
    if df1['blue'][i]==0:
        df1['is_bluetooth'][i]='No'
    else:
        df1['is_bluetooth'][i]='Yes'
px.pie(data_frame = df, names = 'is_bluetooth', title = 'Percentage of devices having bluetooth', hole= 0.2)
# Out:
# <ipython-input-11-f2e348a5f53f>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['is_bluetooth'][i]='No'
# <ipython-input-11-f2e348a5f53f>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['is_bluetooth'][i]='Yes'
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
# ...

# %%
df1
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_width   ram  sc_h  sc_w  talk_time  \
# ...

# %%
#dual sim
df1["is_DualSim"]=''
for i in range(len(df)):
    if df1['dual_sim'][i]==0:
        df1['is_DualSim'][i]='No'
    else:
        df1['is_DualSim'][i]='Yes'
px.pie(data_frame = df, names = 'is_DualSim', title = 'Percentage of devices having dual sim', hole= 0.2)
# Out:
# <ipython-input-13-bf93972af2e4>:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-13-bf93972af2e4>:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
# ...

# %%
#3G
df1["is_3G"]=''
for i in range(len(df)):
    if df1['three_g'][i]==0:
        df1['is_3G'][i]='No'
    else:
        df1['is_3G'][i]='Yes'
px.pie(data_frame = df, names = 'is_3G', title = 'Percentage of devices having 3G connection', hole= 0.2)
# Out:
# <ipython-input-14-0a01f2b2d8a4>:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-14-0a01f2b2d8a4>:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
# ...

# %%
#a=df.drop('price_range',axis=1)
#plt.figure(figsize=(14,8))
#for i, j in enumerate(a):
#    plt.subplot(4,5, i+1)
#    sns.lineplot(y=df[j],x=df["price_range"])
#plt.tight_layout()

# %%
sns.set(rc = {'figure.figsize':(20,15)})
sns.heatmap(df.corr(),annot=True)
# Out:
# <ipython-input-16-f63f237c2cdb>:2: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# <Axes: >

# %%
plt.figure(figsize = (14,6))
plt.subplot(1,2,1,)
sns.barplot (x ='price_range', y = 'px_height' , data=df, palette = 'Reds')
plt.subplot(1,2,2)
sns.barplot(x = 'price_range', y = 'px_width' , data=df , palette = 'Blues')
plt.show()

# %%
plt.figure(figsize = (12,6))
sns.barplot(x = 'price_range', y = 'ram' , data=df)
plt.show()

# %%
plt.figure(figsize = (12,6))
sns.countplot(x = df['three_g'] , hue = df['price_range'] , palette = 'pink')
plt.show()

# %%
plt.figure(figsize = (12,6))
sns.countplot(x = df['four_g'] , hue = df['price_range'] , palette = 'ocean')
plt.show()

# %%
num_col= ['battery_power','clock_speed','fc','int_memory', 'm_dep', 'mobile_wt','pc', 'px_height','px_width', 'ram', 'sc_h', 'sc_w', 'talk_time']
plt.figure(figsize=(15, 7))
for i in range(0, len(num_col)):
    plt.subplot(5, 3, i+1)
    sns.boxplot(x=df[num_col[i]],orient='v')
    plt.tight_layout()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1599: UserWarning:
#
# Vertical orientation ignored with only `x` specified.
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1599: UserWarning:
#
# Vertical orientation ignored with only `x` specified.
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1599: UserWarning:
#
# Vertical orientation ignored with only `x` specified.
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1599: UserWarning:
#
# Vertical orientation ignored with only `x` specified.
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1599: UserWarning:
#
# Vertical orientation ignored with only `x` specified.
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1599: UserWarning:
#
# Vertical orientation ignored with only `x` specified.
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1599: UserWarning:
#
# Vertical orientation ignored with only `x` specified.
#
# ...

# %% [markdown]
# Splitting the data

# %%
x = df.drop(['price_range','is_bluetooth','is_DualSim','is_3G'] , axis = 1)
y = df['price_range']

# %%
#Data splitting to train set and test set
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.3, random_state = 0)

# %%
print("shape of x_train =", x_train.shape)
print("shape of y_train=",y_train.shape)
print("shape of x_test=",x_test.shape)
print("shape of y_test=",y_test.shape)
# Out:
# shape of x_train = (1400, 20)
# shape of y_train= (1400,)
# shape of x_test= (600, 20)
# shape of y_test= (600,)

# %%
x_train
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1719            833     1          0.6         1   0       1          27
# 1702           1424     1          2.9         1   0       0          20
# 1287            860     1          1.3         1   1       1          49
# 482            1330     1          1.3         1  14       0           3
# 768            1149     1          2.2         0   4       0          30
# ...             ...   ...          ...       ...  ..     ...         ...
# 835            1224     1          1.6         0   9       0          33
# 1216           1158     0          0.7         1   1       1          29
# 1653           1190     0          2.0         1   0       0          40
# 559            1191     0          2.4         1   2       0          13
# 684             706     0          0.5         0  13       1          31
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
#standarization
from sklearn.preprocessing import StandardScaler
scaling = StandardScaler()
scaling.fit_transform(x_train,y_train)
# Out:
# array([[-0.90893609,  1.01149463, -1.16524008, ...,  0.55534783,
#         -0.98722446,  0.98159786],
#        [ 0.42822183,  1.01149463,  1.65523128, ...,  0.55534783,
#         -0.98722446, -1.01874713],
#        [-0.84784765,  1.01149463, -0.30683575, ...,  0.55534783,
#          1.01294087,  0.98159786],
#        ...,
#        [-0.10121125, -0.98863599,  0.55156858, ..., -1.80067327,
#         -0.98722446,  0.98159786],
#        [-0.09894872, -0.98863599,  1.04208533, ...,  0.55534783,
#          1.01294087,  0.98159786],
#        [-1.19627797, -0.98863599, -1.28786926, ...,  0.55534783,
#         -0.98722446,  0.98159786]])

# %% [markdown]
# ***1.DECISION Tree***

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier(max_depth=3)
dt_model=dt.fit(x_train,y_train)
y_pred=dt_model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix , accuracy_score, precision_score, recall_score, f1_score,classification_report

print('Accuracy is: ',accuracy_score(y_test,y_pred))
score_de = accuracy_score(y_test,y_pred)*100
# Out:
# Accuracy is:  0.7483333333333333

# %%
import sklearn.metrics as metrics
score=100*(metrics.f1_score(y_test,y_pred,average='macro'))
score
# Out:
# 74.61592622647765

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.82      0.86       151
#            1       0.63      0.76      0.69       135
#            2       0.64      0.58      0.61       151
#            3       0.82      0.83      0.82       163
#
#     accuracy                           0.75       600
#    macro avg       0.75      0.75      0.75       600
# weighted avg       0.76      0.75      0.75       600

# %%
dt = DecisionTreeClassifier(random_state=42)

# %%
from sklearn.model_selection import GridSearchCV

# %%
# Create the parameter grid based on the results of random search
params = {
    'max_depth': [2, 3, 5, 10, 20],
    'min_samples_leaf': [5, 10, 20, 50, 100],
    'criterion': ["gini", "entropy"]
}

# %%
# Instantiate the grid search model
grid_search = GridSearchCV(estimator=dt,
                           param_grid=params,
                           cv=4, n_jobs=-1, verbose=1, scoring = "accuracy")

# %%
GridSearchCV(cv=4, estimator=DecisionTreeClassifier(random_state=42), n_jobs=-1,
             param_grid={'criterion': ['gini', 'entropy'],
                         'max_depth': [2, 3, 5, 10, 20],
                         'min_samples_leaf': [5, 10, 20, 50, 100]},
             scoring='accuracy', verbose=1)
# Out:
# GridSearchCV(cv=4, estimator=DecisionTreeClassifier(random_state=42), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 5, 10, 20],
#                          'min_samples_leaf': [5, 10, 20, 50, 100]},
#              scoring='accuracy', verbose=1)

# %%
dt1 = DecisionTreeClassifier(criterion='entropy', max_depth=10, min_samples_leaf=5,
                       random_state=42)
dt1 = DecisionTreeClassifier(max_depth=3)
dt_model = dt1.fit(x_train,y_train)
y_pred = dt_model.predict(x_test)

# %%
print('Accuracy is: ',accuracy_score(y_test,y_pred))
# Out:
# Accuracy is:  0.7483333333333333

# %% [markdown]
# **2. Random Forest Classifier**

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf_model=rf.fit(x_train,y_train)
y_pred=rf_model.predict(x_test)

# %%
print('Accuracy is: ',accuracy_score(y_test,y_pred))
score_ra = accuracy_score(y_test,y_pred)*100
# Out:
# Accuracy is:  0.87

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95       151
#            1       0.81      0.81      0.81       135
#            2       0.80      0.77      0.79       151
#            3       0.91      0.92      0.91       163
#
#     accuracy                           0.87       600
#    macro avg       0.87      0.87      0.87       600
# weighted avg       0.87      0.87      0.87       600

# %% [markdown]
# **3.Gradient Boosting Classifier**

# %%
from sklearn.ensemble import GradientBoostingClassifier
# Define the gradient boosting classifier model
gb = GradientBoostingClassifier(random_state=42)

# %%
# Train the model on the training data
gb_model=gb.fit(x_train, y_train)
y_pred=gb_model.predict(x_test)

# %%
print('Accuracy is: ',accuracy_score(y_test,y_pred))
score_gr = accuracy_score(y_test,y_pred)*100
# Out:
# Accuracy is:  0.9116666666666666

# %% [markdown]
# **4. XG Boost Classifier**

# %%
import xgboost as xgb

# define the XGBoost model
model = xgb.XGBClassifier()
# train the model on the training data
xgb_model=model.fit(x_train, y_train)
# make predictions on the testing data
y_pred = xgb_model.predict(x_test)

# %%
# evaluate the accuracy of the model
print('Accuracy is: ',accuracy_score(y_test,y_pred))
score_xg = accuracy_score(y_test,y_pred)*100
# Out:
# Accuracy is:  0.9116666666666666

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       151
#            1       0.90      0.86      0.88       135
#            2       0.87      0.86      0.86       151
#            3       0.93      0.94      0.94       163
#
#     accuracy                           0.91       600
#    macro avg       0.91      0.91      0.91       600
# weighted avg       0.91      0.91      0.91       600

# %% [markdown]
# **5.Logistic Regressor**

# %%
# Applying logistic regression

from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# LogisticRegression()

# %%
y_pred_lg = lr.predict(x_test)

print('Accuracy is: ',accuracy_score(y_test,y_pred_lg)*100)
score_lo = accuracy_score(y_test,y_pred_lg)*100
# Out:
# Accuracy is:  63.0

# %% [markdown]
# **6.KNN Classifier**

# %%
from sklearn.neighbors import KNeighborsClassifier
Knn = KNeighborsClassifier(n_neighbors=10)
Knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
pred_knn = Knn.predict(x_test)
print('Accuracy is: ',accuracy_score(y_test,pred_knn)*100)
score_kn = accuracy_score(y_test,pred_knn)*100
# Out:
# Accuracy is:  93.5

# %%
classifiers = ["Logistic Regression", "KNN Classifier", "XGBoost", "Decision Tree", "Random Forest",'Gradient Boost']
Acc_list = [score_lo,score_kn,score_xg,score_de,score_ra,score_gr]
df_models = pd.DataFrame({"Model":classifiers, "Accuracy":Acc_list})
px.histogram(data_frame=df_models, x="Model", y="Accuracy",color = ["red","yellow","blue","orange","green","violet"])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data= {'classifier' : ["Logistic Regression", "KNN Classifier", "XGBoost", "Decision Tree", "Random Forest",'Gradient Boost'],
       'accuracy' : [score_lo,score_kn,score_xg,score_de,score_ra,score_gr]}

# %%
class_acc = pd.DataFrame(data)
class_acc
# Out:
#             classifier   accuracy
# 0  Logistic Regression  63.000000
# 1       KNN Classifier  93.500000
# 2              XGBoost  91.166667
# 3        Decision Tree  74.833333
# 4        Random Forest  87.000000
# 5       Gradient Boost  91.166667

# %%
plt.figure(figsize = (12,6))
sns.barplot(x = 'classifier', y = 'accuracy',data = class_acc)
plt.show()

# %%
#Reading the test dataset
test_df = pd.read_csv('/content/MobileTest.csv')
test_df.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 3    0.5         96  ...  20        295      1752  3893    10     0
# 4    0.5        108  ...  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# ...

# %%
test_df.shape
# Out:
# (1000, 21)

# %%
test_df = test_df.drop(['id'] , axis = 1)
test_df.shape
# Out:
# (1000, 20)

# %%
#making predictions using the test data
test_pred = Knn.predict(test_df)

# %%
test_df['price_range'] = test_pred

# %%
test_df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0           1043     1          1.8         1  14       0           5    0.1
# 1            841     1          0.5         1   4       1          61    0.8
# 2           1807     1          2.8         0   1       0          27    0.9
# 3           1546     0          0.5         1  18       1          25    0.5
# 4           1434     0          1.4         0  11       1          49    0.5
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        193        3  ...        226      1412  3476    12     7          2
# 1        191        5  ...        746       857  3895     6     0          7
# 2        186        3  ...       1270      1366  2396    17    10         10
# 3         96        8  ...        295      1752  3893    10     0          7
# 4        108        6  ...        749       810  1773    15     8          7
#
# ...

# %%
test_df.shape
# Out:
# (1000, 21)

# %% [markdown]
# **combining the train data and test data**

# %%
train_df = pd.read_csv('/content/MobileTrain.csv')

# %%
price_data = pd.concat([train_df,test_df],axis=0)
price_data
# Out:
#      battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0              842     0          2.2         0   1       0           7
# 1             1021     1          0.5         1   0       1          53
# 2              563     1          0.5         1   2       1          41
# 3              615     1          2.5         0   0       0          10
# 4             1821     1          1.2         0  13       1          44
# ..             ...   ...          ...       ...  ..     ...         ...
# 995           1700     1          1.9         0   0       1          54
# 996            609     0          1.8         1   0       0          13
# 997           1185     0          1.4         0   1       1           8
# 998           1533     1          0.5         1   0       0          50
# 999           1270     1          0.5         0   4       1          35
#
#      m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %% [markdown]
# **Ranking Data according to the Price Range**

# %%
data = price_data
data["rank_by_price"] = data["price_range"].rank()
data.head(10)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
# 5           1859     0          0.5         1   3       0          22    0.7
# 6           1821     0          1.7         0   4       1          10    0.8
# 7           1954     0          0.5         1   0       0          24    0.8
# 8           1445     1          0.5         0   0       0          53    0.7
# 9            509     1          0.6         1   2       1           9    0.1
#
#    mobile_wt  n_cores  ...  px_width   ram  sc_h  sc_w  talk_time  three_g  \
# ...

# %% [markdown]
# **Ranking data according to battery power**

# %%
data["rank_by_battery_power"] = data["battery_power"].rank()
data.head(5)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...   ram  sc_h  sc_w  talk_time  three_g  \
# 0        188        2  ...  2549     9     7         19        0
# 1        136        3  ...  2631    17     3          7        1
# 2        145        5  ...  2603    11     2          9        1
# 3        131        6  ...  2769    16     8         11        1
# 4        141        2  ...  1411     8     2         15        1
#
#    touch_screen  wifi  price_range  rank_by_price  rank_by_battery_power
# ...

# %%
data.sort_values(by = 'rank_by_price')
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1791           1203     1          0.5         1   0       1          11
# 564            1152     1          3.0         0   2       0          44
# 644            1715     0          1.9         0   4       1           3
# 646             543     1          0.5         1   4       1          60
# 559            1457     0          0.5         1   7       0           8
# ...             ...   ...          ...       ...  ..     ...         ...
# 1017           1221     0          0.5         0   1       1          28
# 311             992     0          1.6         1  10       0          27
# 313            1979     0          0.5         1  15       0          54
# 1005           1270     1          2.3         0   0       0          58
# 879             906     0          2.1         1   7       0          18
#
#       m_dep  mobile_wt  n_cores  ...   ram  sc_h  sc_w  talk_time  three_g  \
# ...

# %%
#ranking all features in the dataset
r = data.copy()
r["rank_by_battery"] = r["battery_power"].rank(ascending=False,axis=0,method="dense")
r["rank_by_blueooth"] = r["blue"].rank(ascending=False,axis=0,method="dense")
r["rank_by_clockspeed"] = r["clock_speed"].rank(ascending=False,axis=0,method="dense")
r["rank_by_DualSIM"] = r["dual_sim"].rank(ascending=False,axis=0,method="dense")
r["rank_by_fc"] = r["fc"].rank(ascending=False,axis=0,method="dense")
r["rank_by_4G"] = r["four_g"].rank(ascending=False,axis=0,method="dense")
r["rank_by_InternalMemory"] = r["int_memory"].rank(ascending=False,axis=0,method="dense")
r["rank_by_mdep"] = r["m_dep"].rank(ascending=False,axis=0,method="dense")
r["rank_by_weight"] = r["mobile_wt"].rank(ascending=False,axis=0,method="dense")
r["rank_by_ncores"] = r["n_cores"].rank(ascending=False,axis=0,method="dense")
r["rank_by_pc"] = r["pc"].rank(ascending=False,axis=0,method="dense")
r["rank_by_height"] = r["px_height"].rank(ascending=False,axis=0,method="dense")
r["rank_by_width"] = r["px_width"].rank(ascending=False,axis=0,method="dense")
r["rank_by_ram"] = r["ram"].rank(ascending=False,axis=0,method="dense")
r["rank_by_sch"] = r["sc_h"].rank(ascending=False,axis=0,method="dense")
r["rank_by_scw"] = r["sc_w"].rank(ascending=False,axis=0,method="dense")
r["rank_by_talktime"] = r["talk_time"].rank(ascending=False,axis=0,method="dense")
r["rank_by_3G"] = r["three_g"].rank(ascending=False,axis=0,method="dense")
r["rank_by_touchscreen"] = r["touch_screen"].rank(ascending=False,axis=0,method="dense")
r["rank_by_wifi"] = r["wifi"].rank(ascending=False,axis=0,method="dense")
r["rank_by_price"] = r["price_range"].rank(ascending=False,axis=0,method="dense")
r.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  rank_by_pc  rank_by_height  rank_by_width  \
# 0        188        2  ...        19.0          1313.0         1090.0
# 1        136        3  ...        15.0           515.0           11.0
# 2        145        5  ...        15.0           244.0          245.0
# 3        131        6  ...        12.0           277.0          183.0
# 4        141        2  ...         7.0           285.0          696.0
#
#    rank_by_ram  rank_by_sch  rank_by_scw  rank_by_talktime  rank_by_3G  \
# ...

# %%
price=r[["price_range","rank_by_price"]]
price.drop_duplicates("price_range")
# Out:
#    price_range  rank_by_price
# 0            1            3.0
# 1            2            2.0
# 6            3            1.0
# 7            0            4.0

# %%
price=r[["battery_power","rank_by_battery_power"]]
price.drop_duplicates("battery_power")
# Out:
#      battery_power  rank_by_battery_power
# 0              842                  708.0
# 1             1021                 1071.0
# 2              563                  134.5
# 3              615                  243.0
# 4             1821                 2638.0
# ..             ...                    ...
# 972           1198                 1441.0
# 984           1711                 2415.0
# 985            971                  968.0
# 987            905                  833.0
# 991           1797                 2593.0
#
# [1275 rows x 2 columns]
