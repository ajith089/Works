# %%
import numpy as np

import pandas as pd
data = pd.read_csv('/content/StudentsPerformance.csv')

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
#  **TOTAL NO. OF MALE AND FEMALE**

# %%
data.value_counts(data['gender'])
# Out:
# gender
# female    518
# male      482
# dtype: int64

# %%
df = data.groupby(['parental level of education'])[['reading score', 'math score', 'writing score']].describe()
df
# Out:
#                             reading score                                    \
#                                     count       mean        std   min   25%
# parental level of education
# associate's degree                  222.0  71.018018  13.842999  31.0  61.0
# bachelor's degree                   118.0  73.000000  14.285250  41.0  63.0
# high school                         196.0  64.602041  14.245280  24.0  54.0
# master's degree                      59.0  75.949153  13.046896  53.0  66.5
# some college                        226.0  69.566372  14.312932  23.0  60.0
# some high school                    179.0  66.759777  15.710633  17.0  56.5
#
#                                                 math score             ...  \
#                               50%    75%    max      count       mean  ...
# parental level of education                                            ...
# associate's degree           73.0  81.00  100.0      222.0  67.977477  ...
# ...

# %% [markdown]
# parental level of education will affect the perfomance of score.
# students got higher score for the parents having masters degree. As parental level of education increases the Students scores also increases.
# certain students also got 100 with lower parental level of education.

# %% [markdown]
# ### **AVERAGE**

# %%
data.groupby(by = 'gender').mean()
# Out:
# <ipython-input-15-eb409d68565f>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(by = 'gender').mean()
#         math score  reading score  writing score
# gender
# female   63.376448      72.590734      72.467181
# male     68.821577      65.545643      63.446058

# %% [markdown]
# Average Reading score and Writing Score are higher for female. Math score is lower for female than Male

# %%
data.groupby(by = 'test preparation course').mean()
# Out:
# <ipython-input-13-423e002c02b8>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(by = 'test preparation course').mean()
#                          math score  reading score  writing score
# test preparation course
# completed                  69.96648      74.175978      74.684358
# none                       63.78972      66.417445      64.457944

# %% [markdown]
# Course completed students got high scores.

# %% [markdown]
# ### ***VARIANCE***

# %%
data.groupby(by = 'gender').var()
# Out:
# <ipython-input-18-e15bb01891af>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.var is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(by = 'gender').var()
#         math score  reading score  writing score
# gender
# female  256.958593     207.677438     220.369327
# male    211.889097     200.211010     202.413924

# %%
data.groupby(by = 'test preparation course').var()
# Out:
# <ipython-input-17-b0cea7ec479b>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.var is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(by = 'test preparation course').var()
#                          math score  reading score  writing score
# test preparation course
# completed                210.884027     183.265864     175.202612
# none                     246.668662     213.419851     226.251739

# %% [markdown]
# **Top 25% of
# students based on their math score**

# %%
data1 = data.sort_values('math score',ascending = False)
data1.head(250)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 999    male        group E           bachelor's degree      standard
# 996    male        group A                some college      standard
# 515  female        group E                some college      standard
# 517  female        group E          associate's degree      standard
# 516  female        group E           bachelor's degree      standard
# ..      ...            ...                         ...           ...
# 856    male        group E            some high school      standard
# 855    male        group E          associate's degree  free/reduced
# 854    male        group D            some high school      standard
# 853    male        group D          associate's degree  free/reduced
# 852    male        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...
